# %%
# 라이브러리 임포트
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import codecs

# %%
driver = webdriver.Chrome('C:/Users/SJ/data1112/chromedriver.exe')

# %%
rank=0
for i in range(1,251):
    driver.get("http://www.yes24.com/24/category/bestseller?CategoryNumber=001&sumgb=06&fetchSize=40&PageNumber=%s"%i)
    source = driver.page_source
    s1=BeautifulSoup(source,'html.parser')
    s_book = s1.find_all('td',class_='goodsTxtInfo')

    for item in s_book:
        detail_book = item.find_all(['p','div'])
        detail_book[0].find_all('a')[0].text
        detail_book[1].text.strip().replace('\n','').replace('\t','',replace('  ',''))
        detail_book[2].text
# Out:
# [<p>[도서]   <a href="/Product/Goods/80120621">트렌드 코리아 2020</a> : 서울대 소비트렌드분석센터의 2020 전망(포함 경제경영 3만원↑ 구매시 MIGHTY MICE 북커버 + 북마크 세트 증정(포인트차감, 한정수량))
#
# ...
